# %% [markdown]
# # How to use methods in load_data.py

# %% [markdown]
# Begin by importing <code>load_data</code>, which contains the methods to interface with the data files.

# %%
import load_data

# %% [markdown]
# Show how to use the functions to access the dataframes. Here we work with quant tables from MaxQuant or FragPipe.

# %%
df = load_data.load_max_quant()
df
# Out:
#                       Intensity B_C10  Intensity B_C11  Intensity B_C12  \
# Protein IDs
# P0DPI2;A0A0B4J2D5              265300           248290          1878900
# A0AVT1                              0                0           440250
# A6NGU5;P19440                       0                0                0
# A6NHQ2                         126410                0                0
# A6NI72;P14598;A8MVU1          1146300          1354400          2254700
# ...                               ...              ...              ...
# Q9Y5J7                         313760                0                0
# Q9Y5S9                         766910           415980           458400
# Q9Y5X3                         291730           748590          1022100
# Q9Y6C9                              0                0           311590
# Q9Y6N5                              0           121830           440970
#
#                       Intensity B_C13  Intensity B_C9  Intensity T_D10  \
# Protein IDs
# P0DPI2;A0A0B4J2D5              289210               0                0
# A0AVT1                              0               0                0
# A6NGU5;P19440                       0               0                0
# A6NHQ2                          89903               0           263160
# A6NI72;P14598;A8MVU1          2912100         1045700                0
# ...                               ...             ...              ...
# Q9Y5J7                              0               0                0
# Q9Y5S9                         452850          862000           343680
# Q9Y5X3                         133040          510570                0
# Q9Y6C9                              0               0                0
# Q9Y6N5                              0          524620                0
#
#                       Intensity T_D11  Intensity T_D12  Intensity T_D13  \
# Protein IDs
# P0DPI2;A0A0B4J2D5                   0                0                0
# A0AVT1                              0                0                0
# A6NGU5;P19440                       0                0          2590400
# A6NHQ2                              0                0           110120
# A6NI72;P14598;A8MVU1                0                0                0
# ...                               ...              ...              ...
# Q9Y5J7                         259020                0                0
# Q9Y5S9                         495150           551340           766580
# Q9Y5X3                              0                0                0
# Q9Y6C9                         416530                0                0
# Q9Y6N5                        1352300           660590           193530
#
#                       Intensity T_D9
# Protein IDs
# P0DPI2;A0A0B4J2D5             654710
# A0AVT1                             0
# A6NGU5;P19440                      0
# A6NHQ2                             0
# A6NI72;P14598;A8MVU1               0
# ...                              ...
# Q9Y5J7                        237540
# Q9Y5S9                             0
# Q9Y5X3                             0
# Q9Y6C9                             0
# Q9Y6N5                       1067300
#
# [1211 rows x 10 columns]

# %%
df2 = load_data.load_FragPipe()
df2
# Out:
#             Subject1_B_cells_June_C_10  Subject1_B_cells_June_C_11  \
# Protein ID
# A0A0B4J2D5                 1206607.500                   1882145.4
# A0AVT1                      584806.900                    872883.0
# A0FGR8                           0.000                         0.0
# A6NHR9                      655176.100                         0.0
# A8MWD9                      696141.440                   1213763.9
# ...                                ...                         ...
# P43490                        7249.320                         0.0
# P24158                           0.000                         0.0
# Q8IYJ3                           0.000                         0.0
# Q8TD55                       16469.553                         0.0
# Q9BZF1                           0.000                         0.0
#
#             Subject1_B_cells_June_C_12  Subject1_B_cells_June_C_13  \
# Protein ID
# A0A0B4J2D5                 2417132.200                   3093545.2
# A0AVT1                     1135346.800                    543014.9
# A0FGR8                           0.000                         0.0
# A6NHR9                     3419854.500                         0.0
# A8MWD9                      850701.440                   1364050.2
# ...                                ...                         ...
# P43490                      112455.734                         0.0
# P24158                           0.000                         0.0
# Q8IYJ3                           0.000                         0.0
# Q8TD55                           0.000                         0.0
# Q9BZF1                           0.000                         0.0
#
#             Subject1_B_cells_June_C_9  Subject1_T_cells_June_D_10  \
# Protein ID
# A0A0B4J2D5                 1701011.90                   301610.60
# A0AVT1                     2131811.80                        0.00
# A0FGR8                           0.00                        0.00
# A6NHR9                           0.00                   105097.76
# A8MWD9                      633904.00                        0.00
# ...                               ...                         ...
# P43490                           0.00                        0.00
# P24158                      870327.56                        0.00
# Q8IYJ3                           0.00                        0.00
# Q8TD55                           0.00                        0.00
# Q9BZF1                           0.00                        0.00
#
#             Subject1_T_cells_June_D_11  Subject1_T_cells_June_D_12  \
# Protein ID
# A0A0B4J2D5                        0.00                    249601.9
# A0AVT1                       805666.10                         0.0
# A0FGR8                            0.00                         0.0
# A6NHR9                            0.00                         0.0
# A8MWD9                       464729.78                         0.0
# ...                                ...                         ...
# P43490                            0.00                         0.0
# P24158                            0.00                         0.0
# Q8IYJ3                            0.00                         0.0
# Q8TD55                            0.00                         0.0
# Q9BZF1                            0.00                         0.0
#
#             Subject1_T_cells_June_D_13  Subject1_T_cells_June_D_9
# Protein ID
# A0A0B4J2D5                         0.0                  277209.10
# A0AVT1                             0.0                  425896.38
# A0FGR8                             0.0                       0.00
# A6NHR9                             0.0                       0.00
# A8MWD9                             0.0                  446894.66
# ...                                ...                        ...
# P43490                             0.0                       0.00
# P24158                             0.0                       0.00
# Q8IYJ3                             0.0                       0.00
# Q8TD55                             0.0                       0.00
# Q9BZF1                             0.0                       0.00
#
# [1777 rows x 10 columns]

# %% [markdown]
# Note the differences in names, however identifying the Subject 1 B or T cells as those containing "1_B_" or "1_T_" is consistent.

# %% [markdown]
# The columns are the samples. Each row is a protein as identified in each sample.
